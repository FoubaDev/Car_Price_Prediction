# %% [markdown]
# # Prédiction du prix des voitures à travers une application Web
# À partir des données concernant les voitures, faisons un modèle de Machine Learning permettant de prédire le prix des voitures et déployer ce modèle.

# %% [markdown]
# ## 1. Lecture de données

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("car_price_prediction.csv")
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
df.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %% [markdown]
# ## 2. Analyse Exploratoire et Visualisation des données

# %%
df['Price'].unique()
# Out:
# array([13328, 16621,  8467, ..., 56814, 63886, 22075])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(figsize=(15,15))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
sns.countplot(y = df['Manufacturer'])
plt.title("Car companies with their cars", fontsize = 20)
plt.show()

# %%
# on convertit les features en une liste de columns
columns = df.columns.tolist()
columns
# Out:
# ['ID',
#  'Price',
#  'Levy',
#  'Manufacturer',
#  'Model',
#  'Prod. year',
#  'Category',
#  'Leather interior',
#  'Fuel type',
#  'Engine volume',
#  'Mileage',
#  'Cylinders',
#  'Gear box type',
#  'Drive wheels',
#  'Doors',
#  'Wheel',
#  'Color',
#  'Airbags']

# %%
df['Gear box type'].unique()
# Out:
# array(['Automatic', 'Tiptronic', 'Variator', 'Manual'], dtype=object)

# %%
def toFloat(x):
    flt = float(x)
    return flt

def removeKm(x):
    x = x[:-3]
    return toFloat(x)

df.replace({'':np.nan}, inplace = True)

# remplacer le km en float

df['Mileage'] = df['Mileage'].map(lambda x:removeKm(x) )

# transformer le price en float

df['Price'] = df['Price'].map(lambda x:toFloat(x) )

# transformer l'année en float

df['Prod. year'] = df['Prod. year'].map(lambda x:toFloat(x) )

# %% [markdown]
# Donnons un identifiant à chaque caractère de de certains features
# Convertissons nos tableaux en dictionnaire afin d'avoir le couple __clé-valeur__.

# %% [markdown]
# __Cas du feature Model__:

# %%
my_array_model = df['Model'].unique()
my_array_model
# Out:
# array(['RX 450', 'Equinox', 'FIT', ..., 'E 230 124', 'RX 450 F SPORT',
#        'Prius C aqua'], dtype=object)

# %%
my_dict_model = {}
for i ,x in enumerate(my_array_model):
    variable = {x:i+1}
    my_dict_model.update(variable)

# %% [markdown]
# __Cas du feature Manufacturer__:

# %%
my_array_levy = df['Levy'].unique()

# %%
my_dict_levy = {}
for i ,x in enumerate(my_array_levy):
    variable = {x:i+1}
    my_dict_levy.update(variable)

# %% [markdown]
# __Cas du feature Manufacturer__:

# %%
my_array_manufacturer = df['Manufacturer'].unique()

# %%
my_dict_manufacturer = {}
for i ,x in enumerate(my_array_manufacturer):
    variable = {x:i+1}
    my_dict_manufacturer.update(variable)

# %% [markdown]
# __Cas du feature Category__:

# %%
my_array_category = df['Category'].unique()

# %%
my_dict_category = {}
for i ,x in enumerate(my_array_category):
    variable = {x:i+1}
    my_dict_category.update(variable)

# %% [markdown]
# __Cas du feature Leather interior__:

# %%
my_array_leather = df['Leather interior'].unique()

# %%
my_dict_leather = {}
for i ,x in enumerate(my_array_leather):
    variable = {x:i+1}
    my_dict_leather.update(variable)
print(my_dict_leather)
# Out:
# {'Yes': 1, 'No': 2}

# %% [markdown]
# __Cas du feature Fuel type__:

# %%
my_array_fuel = df['Fuel type'].unique()
my_array_fuel
# Out:
# array(['Hybrid', 'Petrol', 'Diesel', 'CNG', 'Plug-in Hybrid', 'LPG',
#        'Hydrogen'], dtype=object)

# %%
my_dict_fuel = {}
for i ,x in enumerate(my_array_fuel):
    variable = {x:i+1}
    my_dict_fuel.update(variable)
print(my_dict_fuel)
# Out:
# {'Hybrid': 1, 'Petrol': 2, 'Diesel': 3, 'CNG': 4, 'Plug-in Hybrid': 5, 'LPG': 6, 'Hydrogen': 7}

# %% [markdown]
# __Cas du feature Engine volume__:

# %%
my_array_engine = df['Engine volume'].unique()

# %%
my_dict_engine = {}
for i ,x in enumerate(my_array_engine):
    variable = {x:i+1}
    my_dict_engine.update(variable)

# %% [markdown]
# __Cas du feature Gear box type__:

# %%
my_array_gearbox = df['Gear box type'].unique()
my_array_gearbox
# Out:
# array(['Automatic', 'Tiptronic', 'Variator', 'Manual'], dtype=object)

# %%
my_dict_gearbox = {}
for i ,x in enumerate(my_array_gearbox):
    variable = {x:i+1}
    my_dict_gearbox.update(variable)
print(my_dict_gearbox)
# Out:
# {'Automatic': 1, 'Tiptronic': 2, 'Variator': 3, 'Manual': 4}

# %% [markdown]
# __Cas du feature Drive wheels__:

# %%
my_array_driverwheel = df['Drive wheels'].unique()
my_array_driverwheel
# Out:
# array(['4x4', 'Front', 'Rear'], dtype=object)

# %%
my_dict_driverwheel = {}
for i ,x in enumerate(my_array_driverwheel):
    variable = {x:i+1}
    my_dict_driverwheel.update(variable)
print(my_dict_driverwheel)
# Out:
# {'4x4': 1, 'Front': 2, 'Rear': 3}

# %% [markdown]
# __Cas du feature Doors__:

# %%
my_array_doors = df['Doors'].unique()
my_array_doors
# Out:
# array(['04-May', '02-Mar', '>5'], dtype=object)

# %%
my_dict_doors = {}
for i ,x in enumerate(my_array_doors):
    variable = {x:i+1}
    my_dict_doors.update(variable)
print(my_dict_doors)
# Out:
# {'04-May': 1, '02-Mar': 2, '>5': 3}

# %% [markdown]
# __Cas du feature Wheel__:

# %%
my_array_wheel = df['Wheel'].unique()
my_array_wheel
# Out:
# array(['Left wheel', 'Right-hand drive'], dtype=object)

# %%
my_dict_wheel = {}
for i ,x in enumerate(my_array_wheel):
    variable = {x:i+1}
    my_dict_wheel.update(variable)
print(my_dict_wheel)
# Out:
# {'Left wheel': 1, 'Right-hand drive': 2}

# %% [markdown]
# __Cas du feature Color__:

# %%
my_array_color = df['Color'].unique()
my_array_color
# Out:
# array(['Silver', 'Black', 'White', 'Grey', 'Blue', 'Green', 'Red',
#        'Sky blue', 'Orange', 'Yellow', 'Brown', 'Golden', 'Beige',
#        'Carnelian red', 'Purple', 'Pink'], dtype=object)

# %%
my_dict_color = {}
for i ,x in enumerate(my_array_color):
    variable = {x:i+1}
    my_dict_color.update(variable)
print(my_dict_color)
# Out:
# {'Silver': 1, 'Black': 2, 'White': 3, 'Grey': 4, 'Blue': 5, 'Green': 6, 'Red': 7, 'Sky blue': 8, 'Orange': 9, 'Yellow': 10, 'Brown': 11, 'Golden': 12, 'Beige': 13, 'Carnelian red': 14, 'Purple': 15, 'Pink': 16}

# %% [markdown]
# Maintenant, remplaçons les valeurs chaque colonnes par celles qui sont dans chaque dictionnaire défini ci-haut.

# %%
df['Manufacturer'] = df['Manufacturer'].map(my_dict_manufacturer)
df['Levy'] = df['Levy'].map(my_dict_levy)
df['Model'] = df['Model'].map(my_dict_model)
df['Category'] = df['Category'].map(my_dict_category)
df['Leather interior'] = df['Leather interior'].map(my_dict_leather)
df['Fuel type'] = df['Fuel type'].map(my_dict_fuel)
df['Engine volume'] = df['Engine volume'].map(my_dict_engine)
df['Gear box type'] = df['Gear box type'].map(my_dict_gearbox)
df['Drive wheels'] = df['Drive wheels'].map(my_dict_driverwheel)
df['Doors'] = df['Doors'].map(my_dict_doors)
df['Wheel'] = df['Wheel'].map(my_dict_wheel)
df['Color'] = df['Color'].map(my_dict_color)
df['Prod. year'] = df['Prod. year'].map(lambda x : toFloat(x))

# %%
df.head()
# Out:
#          ID    Price  Levy  Manufacturer  Model  Prod. year  Category  \
# 0  45654403  13328.0     1             1      1      2010.0         1
# 1  44731507  16621.0     2             2      2      2011.0         1
# 2  45774419   8467.0     3             3      3      2006.0         2
# 3  45769185   3607.0     4             4      4      2011.0         1
# 4  45809263  11726.0     5             3      3      2014.0         2
#
#    Leather interior  Fuel type  Engine volume   Mileage  Cylinders  \
# 0                 1          1              1  186005.0        6.0
# 1                 2          2              2  192000.0        6.0
# 2                 2          2              3  200000.0        4.0
# 3                 1          1              4  168966.0        4.0
# 4                 1          2              3   91901.0        4.0
#
#    Gear box type  Drive wheels  Doors  Wheel  Color  Airbags
# 0              1             1      1      1      1       12
# 1              2             1      1      1      2        8
# 2              3             2      1      2      2        2
# 3              1             1      1      1      3        0
# 4              1             2      1      1      1        4

# %%
df.dtypes
# Out:
# ID                    int64
# Price               float64
# Levy                  int64
# Manufacturer          int64
# Model                 int64
# Prod. year          float64
# Category              int64
# Leather interior      int64
# Fuel type             int64
# Engine volume         int64
# Mileage             float64
# Cylinders           float64
# Gear box type         int64
# Drive wheels          int64
# Doors                 int64
# Wheel                 int64
# Color                 int64
# Airbags               int64
# dtype: object

# %% [markdown]
# Supprimons la colonne ID

# %%
df.drop('ID', inplace=True, axis=1)

# %%
df.head()
# Out:
#      Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328.0     1             1      1      2010.0         1                 1
# 1  16621.0     2             2      2      2011.0         1                 2
# 2   8467.0     3             3      3      2006.0         2                 2
# 3   3607.0     4             4      4      2011.0         1                 1
# 4  11726.0     5             3      3      2014.0         2                 1
#
#    Fuel type  Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  \
# 0          1              1  186005.0        6.0              1             1
# 1          2              2  192000.0        6.0              2             1
# 2          2              3  200000.0        4.0              3             2
# 3          1              4  168966.0        4.0              1             1
# 4          2              3   91901.0        4.0              1             2
#
#    Doors  Wheel  Color  Airbags
# 0      1      1      1       12
# 1      1      1      2        8
# 2      1      2      2        2
# 3      1      1      3        0
# 4      1      1      1        4

# %% [markdown]
# De ce fait ,nous pouvons le vérifier dans la liste de colonnes ci-dessous.

# %%
columns = df.columns.tolist()
columns
# Out:
# ['Price',
#  'Levy',
#  'Manufacturer',
#  'Model',
#  'Prod. year',
#  'Category',
#  'Leather interior',
#  'Fuel type',
#  'Engine volume',
#  'Mileage',
#  'Cylinders',
#  'Gear box type',
#  'Drive wheels',
#  'Doors',
#  'Wheel',
#  'Color',
#  'Airbags']

# %%
plt.figure(figsize=(16,38))

for i, col in enumerate(columns, 1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col], color = '#d1aa00', fill = True, warn_singular=False)
    plt.subplot(8,4,i+11)
    df[col].plot.box()
plt.tight_layout()
plt.show()

# %% [markdown]
# Sur le rendu ci-dessous, on voit qu'il ya des  outliers. Examinons de près grâce à la rélation entre Skewness et Kurtosis.

# %%
pd.DataFrame(data=[df[columns].skew(),df[columns].kurtosis()],index=['skewness','kurtosis'])
# Out:
#                  Price      Levy  Manufacturer     Model  Prod. year  \
# skewness    136.470427  2.422989      2.562077  2.799511   -2.082261
# kurtosis  18824.517329  6.908416      9.237636  8.020927   11.329766
#
#           Category  Leather interior  Fuel type  Engine volume      Mileage  \
# skewness  1.732047          1.009981   1.743057       2.695428    38.896821
# kurtosis  3.601076         -0.980039   3.859278       8.656737  1598.756423
#
#           Cylinders  Gear box type  Drive wheels      Doors     Wheel  \
# skewness   2.091083       1.725017     -0.012095   5.120467  3.169873
# kurtosis   6.486085       1.653707      0.018353  28.108260  8.048933
#
#              Color   Airbags
# skewness  2.233163  0.082012
# kurtosis  5.807393 -1.334021

# %%
from scipy.stats import zscore
for i in columns:
    y_outliers = df[abs(zscore(df[i])) >= 3 ]
    print('Le nombre des outliers de ',i,'est ',len(y_outliers))
    y_outliers
# Out:
# Le nombre des outliers de  Price est  3
# Le nombre des outliers de  Levy est  498
# Le nombre des outliers de  Manufacturer est  441
# Le nombre des outliers de  Model est  665
# Le nombre des outliers de  Prod. year est  150
# Le nombre des outliers de  Category est  746
# Le nombre des outliers de  Leather interior est  0
# Le nombre des outliers de  Fuel type est  893
# Le nombre des outliers de  Engine volume est  460
# Le nombre des outliers de  Mileage est  18
# Le nombre des outliers de  Cylinders est  57
# Le nombre des outliers de  Gear box type est  0
# Le nombre des outliers de  Drive wheels est  0
# Le nombre des outliers de  Doors est  905
# Le nombre des outliers de  Wheel est  1484
# Le nombre des outliers de  Color est  710
# Le nombre des outliers de  Airbags est  0

# %% [markdown]
# Maintenant, mettons le prix suivant une classe ( __Moins chèr,Moyen, Chèr et Très Chèr__).

# %%
def price_class(Price):
    if (Price >=1 and Price<=9278.965):
        return "Moins Cher"
    elif (Price > 9278.965 and Price<=1.855593e+04):
        return "Moyen"
    elif (Price >1.855593e+04  and Price<=27834.895):
        return "Cher"
    else:
        return "Tres Cher"

df['Classe'] = df['Price'].apply(price_class)
df.sample(frac=1).head(10)
# Out:
#          Price  Levy  Manufacturer  Model  Prod. year  Category  \
# 18708  18826.0    16             5     14      2012.0         3
# 11084  15257.0    66             5      7      2010.0         3
# 7350    9722.0     7             6      6      2010.0         3
# 10798   6586.0     3            21    453      2005.0         3
# 12356   5959.0     3             7    384      2000.0         7
# 552    16900.0   147             3    194      2009.0         6
# 8766     188.0     2            10     21      2011.0         1
# 10665   3800.0     3             7     58      2000.0         3
# 4354     549.0    96             6      8      2019.0         3
# 8277   37633.0     3            21    989      2015.0         2
#
#        Leather interior  Fuel type  Engine volume   Mileage  Cylinders  \
# 18708                 1          2              9  112645.0        4.0
# 11084                 1          2              5  205972.0        4.0
# 7350                  1          1              6  400000.0        4.0
# 10798                 2          2              2  198000.0        6.0
# 12356                 1          2             11       0.0        6.0
# 552                   2          2              7  120000.0        4.0
# 8766                  1          2              2  196330.0        6.0
# 10665                 1          3             27    1000.0        6.0
# 4354                  1          2              4   35541.0        4.0
# 8277                  2          2              5   20000.0        4.0
#
#        Gear box type  Drive wheels  Doors  Wheel  Color  Airbags      Classe
# 18708              1             2      1      1      1        4        Cher
# 11084              1             2      1      1      4        4       Moyen
# 7350               3             2      1      1     14        8       Moyen
# 10798              4             2      1      1      5        0  Moins Cher
# 12356              4             3      2      1      2        6  Moins Cher
# 552                1             1      1      1      2        6       Moyen
# 8766               1             1      1      1      3        0  Moins Cher
# 10665              2             3      1      1      1        6  Moins Cher
# 4354               1             2      1      1      2       12  Moins Cher
# 8277               2             2      1      1      2       12   Tres Cher

# %%
df['Classe'].value_counts()
# Out:
# Moins Cher    7119
# Moyen         5721
# Tres Cher     3359
# Cher          3038
# Name: Classe, dtype: int64

# %%
sns.kdeplot(df.loc[df['Classe']=='Moins Cher','Manufacturer'], label='Moins Cher')
sns.kdeplot(df.loc[df['Classe']=='Moyen','Manufacturer'], label='Moyen')
sns.kdeplot(df.loc[df['Classe']=='Cher','Manufacturer'], label='Cher')
sns.kdeplot(df.loc[df['Classe']=='Tres Cher','Manufacturer'], label='Tres Cher')
plt.legend()
plt.show()

# %%
import seaborn as sns
f = plt.figure(figsize=(16,10))
sns.set()
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Traitement des Valeurs abbérrantes
#
# Vérifions si notre dataset ne comporte pas de  valeurs nulles

# %%
df.isnull().sum()
# Out:
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# Classe              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# Classe              0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19232    False
# 19233    False
# 19234    False
# 19235     True
# 19236    False
# Length: 19237, dtype: bool

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#      Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328.0     1             1      1      2010.0         1                 1
# 1  16621.0     2             2      2      2011.0         1                 2
# 2   8467.0     3             3      3      2006.0         2                 2
# 3   3607.0     4             4      4      2011.0         1                 1
# 4  11726.0     5             3      3      2014.0         2                 1
#
#    Fuel type  Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  \
# 0          1              1  186005.0        6.0              1             1
# 1          2              2  192000.0        6.0              2             1
# 2          2              3  200000.0        4.0              3             2
# 3          1              4  168966.0        4.0              1             1
# 4          2              3   91901.0        4.0              1             2
#
#    Doors  Wheel  Color  Airbags      Classe
# 0      1      1      1       12       Moyen
# 1      1      1      2        8       Moyen
# 2      1      2      2        2  Moins Cher
# 3      1      1      3        0  Moins Cher
# 4      1      1      1        4       Moyen

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Supprimons certaines colonnes .

# %%
df.drop('Doors', inplace=True, axis=1)
df.drop('Wheel', inplace=True, axis=1)
df.drop('Leather interior', inplace=True, axis=1)
df.drop('Levy', inplace=True, axis=1)

# %%
df.head()
# Out:
#      Price  Manufacturer  Model  Prod. year  Category  Fuel type  \
# 0  13328.0             1      1      2010.0         1          1
# 1  16621.0             2      2      2011.0         1          2
# 2   8467.0             3      3      2006.0         2          2
# 3   3607.0             4      4      2011.0         1          1
# 4  11726.0             3      3      2014.0         2          2
#
#    Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  Color  \
# 0              1  186005.0        6.0              1             1      1
# 1              2  192000.0        6.0              2             1      2
# 2              3  200000.0        4.0              3             2      2
# 3              4  168966.0        4.0              1             1      3
# 4              3   91901.0        4.0              1             2      1
#
#    Airbags      Classe
# 0       12       Moyen
# 1        8       Moyen
# 2        2  Moins Cher
# 3        0  Moins Cher
# 4        4       Moyen

# %% [markdown]
# ## 5. Entrainement du Modèle

# %%
X = df.iloc[:, 1:12].values
Y = df.iloc[:, 12].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Y = LabelEncoder()
Y = labelencoder_Y.fit_transform(Y)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #### La matrice de confusion
# La matrice de confusion est un outil de mesure de la performance des modèles de classification à 2 classes ou plus.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Importons les bibiliothèques nécéssaires

# %%
import sklearn.linear_model as sk
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Regression Linéaire.

# %%
classifier_LR = LinearRegression()
classifier_LR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print("Le score est  :")
classifier_LR.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.21446848478523628

# %% [markdown]
# Le score est très faible,déterminons l'erreur.

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
predictions = model.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 12.685379857733626

# %% [markdown]
# ### 5.1 Regression Logistique.

# %%
classifier_LR = LogisticRegression(random_state = 0)
classifier_LR.fit(X_train, Y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
print("Le score est  :")
classifier_LR.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.4735503560528993

# %%
Y_pred = classifier_LR.predict(X_test)

# %% [markdown]
# Déterminons la valeur de l'erreur.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=0)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
from sklearn.metrics import mean_squared_error
predictions = model.predict(X_test)
print("L'erreur est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur est :
# 19.35325534079349

# %% [markdown]
# ### 5.2 KNeighbors Classifier

# %%
classifier_KN = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier_KN.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Le score est  :")
classifier_KN.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.5157680569684638

# %%
Y_pred = classifier_KN.predict(X_test)

# %%
model = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import mean_squared_error
predictions = model.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 16.405645981688707

# %% [markdown]
# ### 5.3. SVC en utilisant Vector Machine Algorithm

# %%
from sklearn.svm import SVC
classifier_SVC1 = SVC(kernel = 'linear', random_state = 0)
classifier_SVC1.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
print("Le score est  :")
classifier_SVC1.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.48448626653102744

# %%
from sklearn.metrics import mean_squared_error

model = SVC(kernel = 'linear', random_state = 0)
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 19.449898270600205

# %% [markdown]
# ### 5.4 SVC (Support Vector Class ) en utilisant Kernel  Support Vector Machine Algorithm

# %%
from sklearn.svm import SVC
classifier_SVC2 = SVC(kernel = 'rbf', random_state = 0)
classifier_SVC2.fit(X_train, Y_train)
# Out:
# SVC(random_state=0)

# %%
print("Le score est  :")
classifier_SVC2.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.5236520854526958

# %%
from sklearn.metrics import mean_squared_error

model = SVC(kernel = 'rbf', random_state = 0)
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 16.965666327568666

# %% [markdown]
# ## 5.5  Naïve Bayes Algorithm (GaussianNB)

# %%
from sklearn.naive_bayes import GaussianNB
classifier_NB = GaussianNB()
classifier_NB.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
print("Le score est  :")
classifier_NB.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.29374364191251273

# %%
from sklearn.metrics import mean_squared_error

model = GaussianNB()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 21.77822990844354

# %%
Y_pred = classifier_NB.predict(X_test)

# %% [markdown]
# ## 5.6 Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
classifier_DT = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier_DT.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
print("Le score est  :")
classifier_DT.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.5038148524923703

# %%
from sklearn.metrics import mean_squared_error

model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 15.992624618514752

# %%
Y_pred = classifier_DT.predict(X_test)

# %% [markdown]
# ## 5.7 Random Forest Classification algorithm

# %%
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
classifier_RF = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier_RF.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
print("Le score est  :")
classifier_RF.score(X_test, Y_test)
# Out:
# Le score est  :
# 0.5488301119023398

# %%
Y_pred = classifier_RF.predict(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

model = RandomForestClassifier(n_estimators=100, min_samples_leaf=10, random_state=1)
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
print("L'erreur  est:")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est:
# 13.447863682604273
