# %% [markdown]
# # Prédiction du prix des voitures à travers une application Web
# À partir des données concernant les voitures, faisons un modèle de Machine Learning permettant de prédire le prix des voitures et déployer ce modèle.

# %% [markdown]
# ## 1. Lecture de données

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
import sklearn.linear_model as sk
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor,RandomForestClassifier
import xgboost as xgb
import joblib,pickle 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("car_price_prediction.csv")
df.head(10)
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803   761       TOYOTA     Prius        2010  Hatchback
# 7  45816158    549   751      HYUNDAI    Sonata        2013      Sedan
# 8  45641395   1098   394       TOYOTA     Camry        2014      Sedan
# 9  45756839  26657     -        LEXUS    RX 350        2007       Jeep
#
#   Leather interior Fuel type  Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid            3.5  186005 km          6
# ...

# %%
df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume       float64
# Mileage              object
# Cylinders             int64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
df.describe()
# Out:
#                  ID         Price    Prod. year  Engine volume     Cylinders  \
# count  1.923700e+04  1.923700e+04  19237.000000   19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824       2.307990      4.582991
# std    9.365914e+05  1.905813e+05      5.668673       0.877805      1.199933
# min    2.074688e+07  1.000000e+00   1939.000000       0.000000      1.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000       1.800000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000       2.000000      4.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000       2.500000      4.000000
# max    4.581665e+07  2.630750e+07   2020.000000      20.000000     16.000000
#
#             Airbags
# count  19237.000000
# mean       6.582627
# std        4.320168
# min        0.000000
# 25%        4.000000
# 50%        6.000000
# 75%       12.000000
# max       16.000000

# %% [markdown]
# ## 2. Analyse Exploratoire et Visualisation des données

# %%
df.hist(figsize=(15,15))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
sns.countplot(y = df['Manufacturer'])
plt.title("Les fabricants de car avec leur marque", fontsize = 20)
plt.show()

# %%
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type  Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid            3.5  186005 km          6
# 1               No    Petrol            3.0  192000 km          6
# 2               No    Petrol            1.3  200000 km          4
# 3              Yes    Hybrid            2.5  168966 km          4
# 4              Yes    Petrol            1.3   91901 km          4
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %% [markdown]
# Supprimons la colonne ID

# %%
df.drop('ID', inplace=True, axis=1)

# %%
df.head()
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467     -        HONDA      FIT        2006  Hatchback               No
# 3   3607   862         FORD   Escape        2011       Jeep              Yes
# 4  11726   446        HONDA      FIT        2014  Hatchback              Yes
#
#   Fuel type  Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid            3.5  186005 km          6     Automatic          4x4
# 1    Petrol            3.0  192000 km          6     Tiptronic          4x4
# 2    Petrol            1.3  200000 km          4      Variator        Front
# 3    Hybrid            2.5  168966 km          4     Automatic          4x4
# 4    Petrol            1.3   91901 km          4     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# ...

# %%
columns = df.columns.tolist()

# %%
df["Mileage"] = df["Mileage"].astype(str)
df["Mileage"] = df["Mileage"].str.replace("km", "")
df["Mileage"] = df["Mileage"].str.replace(",", ".")
df["Mileage"] = df["Mileage"].astype(float)
df
# Out:
#        Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399          LEXUS   RX 450        2010       Jeep
# 1      16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2       8467     -          HONDA      FIT        2006  Hatchback
# 3       3607   862           FORD   Escape        2011       Jeep
# 4      11726   446          HONDA      FIT        2014  Hatchback
# ...      ...   ...            ...      ...         ...        ...
# 19232   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type  Engine volume   Mileage  Cylinders  \
# 0                  Yes    Hybrid            3.5  186005.0          6
# ...

# %%
df = df.replace(to_replace="-",value=0)

df['Levy']=df['Levy'].astype("int")
df['Levy'] = df['Levy'].replace(to_replace=0,value=df['Levy'].mean().astype("int"))

# %%
df.dtypes
# Out:
# Price                 int64
# Levy                  int64
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume       float64
# Mileage             float64
# Cylinders             int64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
for col in df.columns :
    if (df[col].dtype) in ['object','boolean']:
        df[col] = df[col].astype('category')
        df[col] = df[col].cat.codes
        
df.head()
# Out:
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399            32   1242        2010         4                 1
# 1  16621  1018             8    658        2011         4                 0
# 2   8467   632            21    684        2006         3                 0
# 3   3607   862            16    661        2011         4                 1
# 4  11726   446            21    684        2014         3                 1
#
#    Fuel type  Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  \
# 0          2            3.5  186005.0          6              0             0
# 1          5            3.0  192000.0          6              2             0
# 2          5            1.3  200000.0          4              3             1
# 3          2            2.5  168966.0          4              0             0
# 4          5            1.3   91901.0          4              0             1
#
#    Doors  Wheel  Color  Airbags
# ...

# %%
plt.figure(figsize=(16,38))

for i, col in enumerate(columns, 1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col], color = '#d1aa00', fill = True, warn_singular=False)
    plt.subplot(8,4,i+11)
    df[col].plot.box()
plt.tight_layout()
plt.show()

# %%
pd.DataFrame(data=[df[columns].skew(),df[columns].kurtosis()],index=['skewness','kurtosis'])
# Out:
#                  Price        Levy  Manufacturer     Model  Prod. year  \
# skewness    136.470427    6.130820      0.162284 -0.061702   -2.082261
# kurtosis  18824.517329  105.603976     -1.156807 -1.121164   11.329766
#
#           Category  Leather interior  Fuel type  Engine volume      Mileage  \
# skewness -0.165874         -1.009981  -0.421426       2.186242    38.896821
# kurtosis -1.654635         -0.980039  -1.587065      19.222583  1598.756423
#
#           Cylinders  Gear box type  Drive wheels      Doors     Wheel  \
# skewness   2.091083       1.369430     -0.012095  -2.953955  3.169873
# kurtosis   6.486085       0.453661      0.018353  17.318528  8.048933
#
#              Color   Airbags
# skewness -0.163907  0.082012
# kurtosis -1.669085 -1.334021

# %% [markdown]
# Nous voyons qu'il ya une mauvaise repartition de valeur skewness et kurtosis. On conclut qu'il existe
# des outliers que nous allons supprime dans certaines colones.

# %%
q1 = df['Price'].quantile(0.25)
q3 = df['Price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
df = df[(df['Price'] > lower_bound) & (df['Price'] < upper_bound)]

# %%
q1 = df['Levy'].quantile(0.25)
q3 = df['Levy'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
df = df[(df['Levy'] > lower_bound) & (df['Levy'] < upper_bound)]

# %%
q1 = df['Prod. year'].quantile(0.25)
q3 = df['Prod. year'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
df = df[(df['Prod. year'] > lower_bound) & (df['Prod. year'] < upper_bound)]

# %%
q1 = df['Engine volume'].quantile(0.25)
q3 = df['Engine volume'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
df = df[(df['Engine volume'] > lower_bound) & (df['Engine volume'] < upper_bound)]

# %%
q1 = df['Mileage'].quantile(0.25)
q3 = df['Mileage'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
df = df[(df['Mileage'] > lower_bound) & (df['Mileage'] < upper_bound)]

# %% [markdown]
# En voulant supprimer les outliers de __Engine Volume__ , il ya un impact sur le feature __Cylinders__ et __Doors__ .
# Cela laisse présager une corrélation entre ces features. Utilisons la fonction exponentielle qui permet de supprimer les outliers en minimisant l'impact.

# %%
def remove_outliers_exp(x, threshold=3):
    exp_x = np.exp(x)
    mean = np.mean(exp_x)
    std = np.std(exp_x)
    lower_bound = mean - threshold * std
    upper_bound = mean + threshold * std
    filtered_x = x[(exp_x >= lower_bound) & (exp_x <= upper_bound)]
    return filtered_x
df['Cylinders'] = remove_outliers_exp(df['Cylinders'])

# %%
pd.DataFrame(data=[df[columns].skew(),df[columns].kurtosis()],index=['skewness','kurtosis'])
# Out:
#              Price      Levy  Manufacturer     Model  Prod. year  Category  \
# skewness  0.679628  0.687853      0.187154 -0.003681   -0.777511 -0.210927
# kurtosis -0.067570  0.301554     -1.289907 -1.122352    0.374047 -1.689994
#
#           Leather interior  Fuel type  Engine volume   Mileage  Cylinders  \
# skewness         -1.017823  -0.335687       0.782520  0.417655   2.539098
# kurtosis         -0.964172  -1.677878       0.267949 -0.193696  11.790848
#
#           Gear box type  Drive wheels      Doors     Wheel     Color   Airbags
# skewness       1.420217     -0.212297  -3.220624  3.009867 -0.247376  0.042144
# kurtosis       0.487109      1.172838  25.104445  7.060294 -1.631062 -1.280441

# %% [markdown]
# Ci-dessous, on voit qu'il ya un changement de valeur. Alors on peut se rassurer que les outliers ne sont plus nombreux comme avant. Nous allons la matrice de corrélation pour voir quels features influent sur le target.

# %%
pd.DataFrame(data=[df[columns].skew(),df[columns].kurtosis()],index=['skewness','kurtosis'])
# Out:
#              Price      Levy  Manufacturer     Model  Prod. year  Category  \
# skewness  0.679628  0.687853      0.187154 -0.003681   -0.777511 -0.210927
# kurtosis -0.067570  0.301554     -1.289907 -1.122352    0.374047 -1.689994
#
#           Leather interior  Fuel type  Engine volume   Mileage  Cylinders  \
# skewness         -1.017823  -0.335687       0.782520  0.417655   2.539098
# kurtosis         -0.964172  -1.677878       0.267949 -0.193696  11.790848
#
#           Gear box type  Drive wheels      Doors     Wheel     Color   Airbags
# skewness       1.420217     -0.212297  -3.220624  3.009867 -0.247376  0.042144
# kurtosis       0.487109      1.172838  25.104445  7.060294 -1.631062 -1.280441

# %%
f = plt.figure(figsize=(18,12))
sns.set()
sns.heatmap(df.corr(), linewidths=.2,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Essayons de comprendre la matrice ci-dessous  en trouvant le feature qui a une corrélation supérieure à 0.5 :

# %%
cor = df.corr()
threshold = 0.5
a=abs(cor['Price'])
result = a[a>0.5]
result
# Out:
# Price    1.0
# Name: Price, dtype: float64

# %% [markdown]
# Nous constatons qu'aucun feature n'a une corrélation supérieure à 0.5 avec le target Price.
# Maintenant, mettons le prix suivant une classe ( __Moins chèr,Moyen, Chèr et Très Chèr__).

# %%
def price_class(Price):
    if (Price >=1 and Price<=9278.965):
        return "Moins Cher"
    elif (Price > 9278.965 and Price<=1.855593e+04):
        return "Moyen"
    elif (Price >1.855593e+04  and Price<=27834.895):
        return "Cher"
    else:
        return "Tres Cher"

df['Classe'] = df['Price'].apply(price_class)
df.head()
# Out:
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 1  16621  1018             8    658        2011         4                 0
# 2   8467   632            21    684        2006         3                 0
# 3   3607   862            16    661        2011         4                 1
# 4  11726   446            21    684        2014         3                 1
# 5  39493   891            23   1305        2016         4                 1
#
#    Fuel type  Engine volume   Mileage  Cylinders  Gear box type  Drive wheels  \
# 1          5            3.0  192000.0        6.0              2             0
# 2          5            1.3  200000.0        4.0              3             1
# 3          2            2.5  168966.0        4.0              0             0
# 4          5            1.3   91901.0        4.0              0             1
# 5          1            2.0  160931.0        4.0              0             1
#
# ...

# %% [markdown]
# Voyons le nombre de différentes de la colonne classe :

# %%
df['Classe'].value_counts()
# Out:
# Moyen         4745
# Moins Cher    4640
# Cher          2787
# Tres Cher     1984
# Name: Classe, dtype: int64

# %% [markdown]
# Examinons graphiquement la répartition de __price__ en fonction du feature __Cylinders__

# %%
sns.kdeplot(df.loc[df['Classe']=='Moins Cher','Cylinders'], label='Moins Cher')
sns.kdeplot(df.loc[df['Classe']=='Moyen','Cylinders'], label='Moyen')
sns.kdeplot(df.loc[df['Classe']=='Cher','Cylinders'], label='Cher')
sns.kdeplot(df.loc[df['Classe']=='Tres Cher','Cylinders'], label='Tres Cher')
plt.legend()
plt.show()

# %% [markdown]
# Voyons graphiquement la répartition de __price__ en fonction du feature __Airbags__

# %%
sns.kdeplot(df.loc[df['Classe']=='Moins Cher','Airbags'], label='Moins Cher')
sns.kdeplot(df.loc[df['Classe']=='Moyen','Airbags'], label='Moyen')
sns.kdeplot(df.loc[df['Classe']=='Cher','Airbags'], label='Cher')
sns.kdeplot(df.loc[df['Classe']=='Tres Cher','Airbags'], label='Tres Cher')
plt.legend()
plt.show()

# %% [markdown]
# Prenons le cas de __Mileage__ :

# %%
sns.kdeplot(df.loc[df['Classe']=='Moins Cher','Mileage'], label='Moins Cher')
sns.kdeplot(df.loc[df['Classe']=='Moyen','Mileage'], label='Moyen')
sns.kdeplot(df.loc[df['Classe']=='Cher','Mileage'], label='Cher')
sns.kdeplot(df.loc[df['Classe']=='Tres Cher','Mileage'], label='Tres Cher')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Traitement des Valeurs abbérrantes
#
# Vérifions si notre dataset ne comporte pas de  valeurs nulles.

# %%
df.isnull().sum()
# Out:
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           5
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# Classe              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           5
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# Classe              0
# dtype: int64

# %%
df.duplicated()
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 19230    False
# 19231     True
# 19233    False
# 19234    False
# 19236    False
# Length: 14156, dtype: bool

# %%
df.dropna(how='all', inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.fillna(0, inplace=True)
df
# Out:
#        Price  Levy  Manufacturer  Model  Prod. year  Category  \
# 1      16621  1018             8    658        2011         4
# 2       8467   632            21    684        2006         3
# 3       3607   862            16    661        2011         4
# 4      11726   446            21    684        2014         3
# 5      39493   891            23   1305        2016         4
# ...      ...   ...           ...    ...         ...       ...
# 19229     50   632            58   1154        2008         3
# 19230    470   645            58   1154        2011         3
# 19233  15681   831            23   1334        2011         9
# 19234  26108   836            23   1442        2010         4
# 19236    470   753            23   1334        2012         9
#
#        Leather interior  Fuel type  Engine volume   Mileage  Cylinders  \
# 1                     0          5            3.0  192000.0        6.0
# 2                     0          5            1.3  200000.0        4.0
# ...

# %%
df.shape
# Out:
# (11755, 18)

# %% [markdown]
# Visualisons encore certains features :

# %%
sns.kdeplot(df.loc[df['Classe']=='Moins Cher','Gear box type'], label='Moins Cher')
sns.kdeplot(df.loc[df['Classe']=='Moyen','Gear box type'], label='Moyen')
sns.kdeplot(df.loc[df['Classe']=='Cher','Gear box type'], label='Cher')
sns.kdeplot(df.loc[df['Classe']=='Tres Cher','Gear box type'], label='Tres Cher')
plt.legend()
plt.show()

# %% [markdown]
# Cas d'année de fabrication :

# %%
sns.kdeplot(df.loc[df['Classe']=='Moins Cher','Prod. year'], label='Moins Cher')
sns.kdeplot(df.loc[df['Classe']=='Moyen','Prod. year'], label='Moyen')
sns.kdeplot(df.loc[df['Classe']=='Cher','Prod. year'], label='Cher')
sns.kdeplot(df.loc[df['Classe']=='Tres Cher','Prod. year'], label='Tres Cher')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Entrainement du Modèle

# %% [markdown]
# Isolons une variable X qui representera le dataframe __df__ sans les colonnes __Price__ et __Clase__ :

# %%
X = df.drop(['Price','Classe'],axis=1)
X
# Out:
#        Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 1      1018             8    658        2011         4                 0
# 2       632            21    684        2006         3                 0
# 3       862            16    661        2011         4                 1
# 4       446            21    684        2014         3                 1
# 5       891            23   1305        2016         4                 1
# ...     ...           ...    ...         ...       ...               ...
# 19229   632            58   1154        2008         3                 0
# 19230   645            58   1154        2011         3                 1
# 19233   831            23   1334        2011         9                 1
# 19234   836            23   1442        2010         4                 1
# 19236   753            23   1334        2012         9                 1
#
#        Fuel type  Engine volume   Mileage  Cylinders  Gear box type  \
# ...

# %% [markdown]
# De même, une variable Y prendra la colonne de notre target __Price__

# %%
Y = df['Price']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, train_size=0.7,random_state=42)

# %%
labelencoder_Y = LabelEncoder()
Y = labelencoder_Y.fit_transform(Y)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Nous allons utiliser les différents modèles ci-dessous pour voir lequel donne une bonne précision.

# %% [markdown]
# ## 3.1  Regression Linéaire.

# %%
linear_regression = LinearRegression()
linear_regression.fit(X_train, Y_train)
Y_pred = linear_regression.predict(X_test)

# %%
linear_score =round(r2_score(Y_test,Y_pred)*100,4)
print("Le score %  est  de:")
linear_score
# Out:
# Le score %  est  de:
# 25.8602

# %% [markdown]
# Le score est très faible,déterminons l'erreur.

# %%
print("Le prix predit est :\n")
print(linear_regression.predict([[1018,8,658,2011,4,0,5,3.0,192000.0,6,2,0,1,0,1,8]]),"\n")
print("Et le prix réel est :\n")
print(df['Price'][1])
# Out:
# Le prix predit est :
#
# [-2.41614146e+08]
#
# Et le prix réel est :
#
# 16621

# %%
predictions = linear_regression.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 93401749.79214557

# %% [markdown]
# ### 3.2  KNeighbors Regressor

# %%
kneighbor = KNeighborsRegressor(n_neighbors = 4)
kneighbor.fit(X_train, Y_train)
Y_pred = kneighbor.predict(X_test)

# %%
kneighbor_score = round(r2_score(Y_test,Y_pred)*100,4)
print("Le score %  est  de:")
kneighbor_score
# Out:
# Le score %  est  de:
# 59.9255

# %%
print("le prix predit est :\n")
print(kneighbor.predict([[1018,8,658,2011,4,0,5,3.0,192000.0,6,2,0,1,0,1,8]]),"\n")
print("Et le prix réel est :\n")
print(df['Price'][1])
# Out:
# le prix predit est :
#
# [9741.5]
#
# Et le prix réel est :
#
# 16621

# %%
predictions = kneighbor.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 50486120.33488092

# %% [markdown]
# ## 3.3 Decision Tree Algorithm

# %%
dt_regressor = DecisionTreeRegressor(criterion = 'poisson', random_state = 42)
dt_regressor.fit(X_train, Y_train)
Y_pred = dt_regressor.predict(X_test)

# %%
decision_score = round(r2_score(Y_test,Y_pred)*100,4)
print("Le score %  est  de:")
decision_score
# Out:
# Le score %  est  de:
# 46.8273

# %%
print("le prix predit est :\n")
print(dt_regressor.predict([[1018,8,658,2011,4,0,5,3.0,192000.0,6,2,0,1,0,1,8]]),"\n")

print("Et le prix réel est :\n")
print(df['Price'][1])
# Out:
# le prix predit est :
#
# [21326.]
#
# Et le prix réel est :
#
# 16621

# %%
predictions = dt_regressor.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 66987207.50529251

# %% [markdown]
# ## 3.4 BaggingRegressor

# %%
bagging_reg = BaggingRegressor(random_state=42)
bagging_reg.fit(X_train, Y_train)
Y_pred = bagging_reg.predict(X_test)

# %%
bagging_score = round(r2_score(Y_test,Y_pred)*100,4)
print("Le score %  est  de:")
bagging_score
# Out:
# Le score %  est  de:
# 69.289

# %%
print("le prix predit est :\n")
print(bagging_reg.predict([[1018,8,658,2011,4,0,5,3.0,192000.0,6,2,0,1,0,1,8]]),"\n")

print("Et le prix réel est : \n")
print(df['Price'][1])
# Out:
# le prix predit est :
#
# [29050.4]
#
# Et le prix réel est :
#
# 16621

# %%
predictions = bagging_reg.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 38689923.66074482

# %% [markdown]
# ## 3.5  AdaBoost

# %%
adaboost = AdaBoostRegressor(DecisionTreeRegressor(max_depth=24),
    n_estimators=200,learning_rate=0.6
)
adaboost.fit(X_train, Y_train)
Y_pred = adaboost.predict(X_test)

# %%
adaboost_score = round(r2_score(Y_test,Y_pred)*100,4)
print("Le score %  est  de:")
adaboost_score
# Out:
# Le score %  est  de:
# 71.0054

# %%
print("le prix predit est :\n")
print(adaboost.predict([[1018,8,658,2011,4,0,5,3.0,192000.0,6,2,0,1,0,1,8]]),"\n")
print("Et le prix réel est : \n")
print(df['Price'][1])
# Out:
# le prix predit est :
#
# [25086.]
#
# Et le prix réel est :
#
# 16621

# %%
predictions = adaboost.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 36527511.51673692

# %% [markdown]
# ## 3.6 XGBOOST

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate = 0.4,
                max_depth = 24, alpha = 5, n_estimators = 200)
xg_reg.fit(X_train,Y_train)
Y_pred = xg_reg.predict(X_test)

# %%
xgboost_score =round(r2_score(Y_test,Y_pred)*100,4)
print("xg score %  est  de:")
xgboost_score
# Out:
# xg score %  est  de:
# 67.4949

# %%
print("le prix predit est :\n")
print(xg_reg.predict([[1018,8,658,2011,4,0,5,3.0,192000.0,6,2,0,1,0,1,8]]),"\n")
print("Et le prix réel est : \n")
print(df['Price'][1])
# Out:
# le prix predit est :
#
# [20854.24]
#
# Et le prix réel est :
#
# 16621

# %%
predictions = xg_reg.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 40950111.925531656

# %% [markdown]
# ##  3.7 Random Forest Regressor algorithm

# %%
random_fr = RandomForestRegressor(n_estimators=100,random_state=42)
random_fr.fit(X_train, Y_train)
Y_pred = random_fr.predict(X_test)
random_score = round(r2_score(Y_test,Y_pred)*100,4)
print("Le score %  est  de:")
random_score
# Out:
# Le score %  est  de:
# 72.2023

# %%
print("le prix predit est")
print(random_fr.predict([[1018,8,658,2011,4,0,5,3.0,192000.0,6,2,0,1,0,1,8]]),"\n")
print("Et le prix réel est :")
print(df['Price'][1])
# Out:
# le prix predit est
# [26148.7]
#
# Et le prix réel est :
# 16621

# %%
predictions = random_fr.predict(X_test)
print("L'erreur  est :")
mean_squared_error(predictions, Y_test)
# Out:
# L'erreur  est :
# 35019667.69430996

# %%
import matplotlib.pyplot as plt

models = ['random forest', 'XGBOOST', 'Bagging Regressor', 'Adaboost', 'Decision Tree', 'K neighbours','Linear Regressor']
scores = [random_score , xgboost_score, bagging_score,adaboost_score,decision_score,kneighbor_score,linear_score]


plt.figure(figsize=(12, 8))
plt.bar(models, scores, color='green')
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Model Scores')

plt.show()

# %%
import matplotlib.pyplot as plt

models = ['random forest', 'XGBOOST', 'Bagging Regressor', 'Adaboost', 'Decision Tree', 'K neighbours','Linear Regressor']
scores = [random_score , xgboost_score, bagging_score,adaboost_score,decision_score,kneighbor_score,linear_score]


plt.figure(figsize=(12, 8))
plt.plot(models, scores, color='blue')
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Model Scores')

plt.show()

# %% [markdown]
# Exportons notre modèle au format sav pour l'utiliser dans streamlit.

# %%
joblib.dump(random_fr, "car_price_prediction.sav")
# Out:
# ['car_price_prediction.sav']

# %% [markdown]
# Enregistrons  note dataframe pour l'utiliser

# %%
df.to_csv("car_price_cleaned.csv")
